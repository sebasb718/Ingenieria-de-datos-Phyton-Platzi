# %%
print ('Hello world')
# Out:
# Hello world

# %%
print("segunda linea")
# Out:
# segunda linea

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ## Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.141516
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'Sebas'

# %% [markdown]
# ## Estructurados

# %%
from IPython.display import Image

Image('sqlImage.png')

# %% [markdown]
# ## Semi estructurados

# %%
Image('htmlImage.png')

# %% [markdown]
# ## No estructurados

# %% [markdown]
# Hola a todos
# esto es un texto
# y es no estructurado

# %% [markdown]
# # Solicitudes a la web

# %%
import requests

response = requests.get('https://www.platzi.com')

print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %% [markdown]
# # Extracción de información del HTML

# %%
import bs4

response.encoding = 'utf-8'
soup = bs4.BeautifulSoup(response.text, 'html.parser')

courses_links = soup.select('.RecentCourses-item > a')
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /cursos/tensorflow-js
# /cursos/economia-digital
# /cursos/finanzas-personales
# /cursos/flujo-c-2020
# /cursos/ingles-principiantes
# /cursos/financiamiento
# /cursos/scrapy
# /cursos/estrategias-ingles
# /cursos/reclutamiento-talento
# /cursos/textura-3dmaya
# /cursos/estrategias-comunicar
# /cursos/pythonbasico
# /cursos/whatsapp-business
# /cursos/curso-de-thick-data
# /cursos/taller-startups-2020

# %%
import bs4
import requests

response = requests.get('https://www.eltiempo.com')
response.encoding = 'utf-8'

soup = bs4.BeautifulSoup(response.text, 'html.parser')

articles_containers = soup.select('.title-container a')
news = {}
for article in articles_containers:
    news[article.text] = article['href']
    
news
# Out:
# {'Atención: Alcalde de Cali decreta el toque de queda por covid-19': '/colombia/cali/alcalde-declara-alerta-roja-por-zonas-ante-el-covid-19-en-cali-518540',
#  'Detención de Aníbal Gaviria es proporcional, idónea y necesaria: Corte': '/justicia/cortes/anibal-gaviria-corte-mantiene-la-detencion-del-suspendido-gobernador-de-antioquia-518374',
#  'Claudia López le presentaría a Duque propuesta de cuarentena general': '/bogota/cuarentena-en-bogota-claudia-lopez-presentaria-propuesta-de-cuarentena-general-a-duque-518614',
#  'Dos pacientes con covid-19 visitaron centros comerciales': '/colombia/otras-ciudades/coronavirus-en-colombia-contagiados-que-violaron-la-cuarentena-podrian-ir-presos-noticias-hoy-518372',
#  'Video': '/salud/coronavirus-errores-que-pueden-resultar-mortales-en-la-pandemia-517660',
#  'Hay 189 nuevas muertes por covid-19; ya van más de 70 mil recuperados': '/salud/coronavirus-en-colombia-contagios-muertos-y-cuarentena-hoy-15-de-julio-518464',
# ...

# %% [markdown]
# # Series

# %%
import pandas as pd

series_test = pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # Dataframes

# %%
frame_test = pd.DataFrame({1999: [74, 65, 56],
                           2000: [34, 54, 53],
                           2001: [12, 87, 75],})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    12
# 1    65    54    87
# 2    56    53    75

# %%
frame_test2 = pd.DataFrame([[74, 65, 56],
                            [34, 54, 53],
                            [12, 87, 75]], columns=[1999, 2000, 2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    65    56
# 1    34    54    53
# 2    12    87    75

# %% [markdown]
# # Read data

# %%
#el_tiempo = pd.read_csv('../web_scrapper/eltiempo_2020_07_14_articles.csv')
el_universal = pd.read_csv('../web_scrapper/eluniversal_2020_07_14_articles.csv')

el_universal
# Out:
#                                                   body  \
# 0    \nCuando los pulmones son débiles es más fácil...
# 1    \nLa plática entre Pedro y su hijo fue interru...
# 2    \nEn los últimos cinco días hábiles de semana,...
# 3    \n\nDurante la pandemia, mientras las construc...
# 4    \nCon los gimnasios cerrados debido al Covid-1...
# ..                                                 ...
# 130  \n\nDesde Zacatecas nos cuentan que este fin d...
# 131  \n\nHace poco, el señor Ackerman equiparó a qu...
# 132  \n\nTras haber sido derrotado ampliamente en l...
# 133  \nPoco a poco en algunos países del mundo, la ...
# 134  \nMiami.- La audiencia para fijar fianza al ex...
#
#                                                  title  \
# 0    Alimentos que pueden perjudicar la salud pulmonar
# 1    Tras asalto, persigue a delincuentes y lo mata...
# 2     Cada hora, Querétaro reporta 2 casos de Covid-19
# 3    "Unión Tepito" le pega a la industria de la co...
# ...

# %% [markdown]
# # Index and selection

# %%
#dictionary like 
el_universal['title']
# Out:
# 0      Alimentos que pueden perjudicar la salud pulmonar
# 1      Tras asalto, persigue a delincuentes y lo mata...
# 2       Cada hora, Querétaro reporta 2 casos de Covid-19
# 3      "Unión Tepito" le pega a la industria de la co...
# 4      Lanzan saco de box inteligente para entrenar e...
#                              ...
# 130    Senador da ayudadita a carrera política de su ...
# 131             …pero algunos son más Ackerman que otros
# 132                                 Un éxito, la visita
# 133    La reacción de Tom Holland ante incómoda prueb...
# 134    Audiencia de César Duarte para fijar fianza se...
# Name: title, Length: 135, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0    Alimentos que pueden perjudicar la salud pulmonar
# 1    Tras asalto, persigue a delincuentes y lo mata...
# 2     Cada hora, Querétaro reporta 2 casos de Covid-19
# 3    "Unión Tepito" le pega a la industria de la co...
# 4    Lanzan saco de box inteligente para entrenar e...
# ..                                                 ...
# 130  Senador da ayudadita a carrera política de su ...
# 131           …pero algunos son más Ackerman que otros
# 132                               Un éxito, la visita
# 133  La reacción de Tom Holland ante incómoda prueb...
# 134  Audiencia de César Duarte para fijar fianza se...
#
#                                                    url
# 0    http://www.eluniversal.com.mx/menu/que-aliment...
# 1    http://www.eluniversal.com.mx/metropoli/cdmx/t...
# 2    https://www.eluniversalqueretaro.mx/portada/se...
# 3    http://www.eluniversal.com.mx/metropoli/union-...
# ...

# %%
#numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nA partir del 15 de julio, comenzarán a opera...
# 11  \n\n\n\n    googletag.cmd.push(function() {\n ...
# 12  \nLa pandemia por coronavirus no sólo ha sido ...
# 13  \nLa cantante Jennifer Lopez fue captada mient...
# 14  \nTras los cuestionamientos que día a día crec...
#
#                                                 title  \
# 10  Alistan para este miércoles, kioscos para dete...
# 11  Curvy Zelma, de Venga la Alegría a Survivor Mé...
# 12                                                NaN
# 13                                                NaN
# 14                          La vacuna de López-Gatell
#
#                                                   url
# 10  http://www.eluniversal.com.mx/metropoli/cdmx/a...
# 11  http://www.unionyucatan.mx/articulo/2020/07/05...
# 12  https://www.viveusa.mx/negocios/buscan-mecanic...
# 13  https://www.viveusa.mx/showbiz/jennifer-lopez-...
# ...

# %%
el_universal.iloc[66]['title']
# Out:
# ' Bienestar Azteca, lo que debes saber del registro e iniciar sesión'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nCuando los pulmones son débiles es más fácil...
# 1    \nLa plática entre Pedro y su hijo fue interru...
# 2    \nEn los últimos cinco días hábiles de semana,...
# 3    \n\nDurante la pandemia, mientras las construc...
# 4    \nCon los gimnasios cerrados debido al Covid-1...
# Name: body, dtype: object

# %%
el_universal.loc[:, 'body':'title']
# Out:
#                                                   body  \
# 0    \nCuando los pulmones son débiles es más fácil...
# 1    \nLa plática entre Pedro y su hijo fue interru...
# 2    \nEn los últimos cinco días hábiles de semana,...
# 3    \n\nDurante la pandemia, mientras las construc...
# 4    \nCon los gimnasios cerrados debido al Covid-1...
# ..                                                 ...
# 130  \n\nDesde Zacatecas nos cuentan que este fin d...
# 131  \n\nHace poco, el señor Ackerman equiparó a qu...
# 132  \n\nTras haber sido derrotado ampliamente en l...
# 133  \nPoco a poco en algunos países del mundo, la ...
# 134  \nMiami.- La audiencia para fijar fianza al ex...
#
#                                                  title
# 0    Alimentos que pueden perjudicar la salud pulmonar
# 1    Tras asalto, persigue a delincuentes y lo mata...
# 2     Cada hora, Querétaro reporta 2 casos de Covid-19
# 3    "Unión Tepito" le pega a la industria de la co...
# ...

# %% [markdown]
# # Data wrangling

# %%
# 1. Añadir el newspaper_uid al DataFrame
el_universal['newspaper_uid'] = 'eluniversal'
el_universal
# Out:
#                                                   body  \
# 0    \nCuando los pulmones son débiles es más fácil...
# 1    \nLa plática entre Pedro y su hijo fue interru...
# 2    \nEn los últimos cinco días hábiles de semana,...
# 3    \n\nDurante la pandemia, mientras las construc...
# 4    \nCon los gimnasios cerrados debido al Covid-1...
# ..                                                 ...
# 130  \n\nDesde Zacatecas nos cuentan que este fin d...
# 131  \n\nHace poco, el señor Ackerman equiparó a qu...
# 132  \n\nTras haber sido derrotado ampliamente en l...
# 133  \nPoco a poco en algunos países del mundo, la ...
# 134  \nMiami.- La audiencia para fijar fianza al ex...
#
#                                                  title  \
# 0    Alimentos que pueden perjudicar la salud pulmonar
# 1    Tras asalto, persigue a delincuentes y lo mata...
# 2     Cada hora, Querétaro reporta 2 casos de Covid-19
# 3    "Unión Tepito" le pega a la industria de la co...
# ...

# %%
# 2. Obtener el host
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)
el_universal
# Out:
#                                                   body  \
# 0    \nCuando los pulmones son débiles es más fácil...
# 1    \nLa plática entre Pedro y su hijo fue interru...
# 2    \nEn los últimos cinco días hábiles de semana,...
# 3    \n\nDurante la pandemia, mientras las construc...
# 4    \nCon los gimnasios cerrados debido al Covid-1...
# ..                                                 ...
# 130  \n\nDesde Zacatecas nos cuentan que este fin d...
# 131  \n\nHace poco, el señor Ackerman equiparó a qu...
# 132  \n\nTras haber sido derrotado ampliamente en l...
# 133  \nPoco a poco en algunos países del mundo, la ...
# 134  \nMiami.- La audiencia para fijar fianza al ex...
#
#                                                  title  \
# 0    Alimentos que pueden perjudicar la salud pulmonar
# 1    Tras asalto, persigue a delincuentes y lo mata...
# 2     Cada hora, Querétaro reporta 2 casos de Covid-19
# 3    "Unión Tepito" le pega a la industria de la co...
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         76
# www.viveusa.mx                 14
# de10.com.mx                     7
# www.eluniversalqueretaro.mx     6
# oaxaca.eluniversal.com.mx       6
# www.elgrafico.mx                6
# sanluis.eluniversal.com.mx      6
# www.unionyucatan.mx             3
# www.unionjalisco.mx             3
# www.unionedomex.mx              2
# www.unioncdmx.mx                2
# www.unionguanajuato.mx          2
# www.unionpuebla.mx              1
# www.clubeluniversal.mx          1
# Name: host, dtype: int64

# %% [markdown]
# # Missing data

# %%
# 3. Rellenar datos faltantes
missing_titles_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_titles_mask]['url']
                     .str.extract(r'(?P<missing_titles>[^/]+)$')
                     .applymap(lambda title: title.replace('-',' ')))
missing_titles
# Out:
#                                         missing_titles
# 5    las razas de perros artificiales con mas probl...
# 12   buscan mecanicos mexicanos para trabajar en ca...
# 13   jennifer lopez luce figura con top y leggings ...
# 17   duelo de divas las 10 mejores actrices de la e...
# 20   quien era el nieto de elvis presley y por que ...
# 23   acribillan cinco policias cuando se echaban un...
# 29                 chipilo la pequena italia de mexico
# 35   eiza gonzalez presume abs de impacto con top d...
# 36     la tragica desaparicion y muerte de naya rivera
# 40   las fotos de la influencer que muestra sus imp...
# 41   chofer y pasajera mueren tras chocar vs la cam...
# 48   el amor prohibido de maria felix y su hermano ...
# 51   papa e hijo son asaltados en la cdmx uno de el...
# 57   cual es el riesgo de contraer coronavirus en u...
# 60      cancelan el maraton de chicago por coronavirus
# 61   emiten alerta sanitaria por ardilla con peste ...
# ...

# %% [markdown]
# # Additional cleanup

# %%
# 4. Añadir uid a las filas
import hashlib

uids = (el_universal
           .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
           .apply(lambda hash_object: hash_object.hexdigest()))
el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True) #inplace es para modificar el df actual, de lo contrario crea uno nuevo
el_universal
# Out:
#                                                                                body  \
# uid
# c267d0c20793a5fdd61dfd9f753b58dc  \nCuando los pulmones son débiles es más fácil...
# 7ba0433f329bb63902f7e58e6de0cbba  \nLa plática entre Pedro y su hijo fue interru...
# 8fbe32c7fa43f2022ae7ef6336ff2f57  \nEn los últimos cinco días hábiles de semana,...
# 90af304f4d324a6d445e029897f989d5  \n\nDurante la pandemia, mientras las construc...
# 1bf09eeed12fc0dca53a30a742ed2cf1  \nCon los gimnasios cerrados debido al Covid-1...
# ...                                                                             ...
# caa470e258a8fabe409c660594ffb397  \n\nDesde Zacatecas nos cuentan que este fin d...
# f7d345b304b60282d4bde07c06121152  \n\nHace poco, el señor Ackerman equiparó a qu...
# fb76b5597c8f404f97f4089393ea6344  \n\nTras haber sido derrotado ampliamente en l...
# 9004611e575e006ae18bc5a9e2193072  \nPoco a poco en algunos países del mundo, la ...
# ...

# %%
stripped_body = (el_universal
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: body.replace('\n',''))
                )
el_universal['body'] = stripped_body

# %% [markdown]
# # Data enrichment

# %%
# 6. Tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

# Para instalar nltk la primera vez
#nltk.download('punkt')
#nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return(df
            .dropna()
            .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
            .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
            .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
            .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
            .apply(lambda valid_world_list: len(valid_world_list))
          )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')

el_universal
# Out:
#                                                                                body  \
# uid
# c267d0c20793a5fdd61dfd9f753b58dc  Cuando los pulmones son débiles es más fácil q...
# 7ba0433f329bb63902f7e58e6de0cbba  La plática entre Pedro y su hijo fue interrump...
# 8fbe32c7fa43f2022ae7ef6336ff2f57  En los últimos cinco días hábiles de semana, q...
# 90af304f4d324a6d445e029897f989d5  Durante la pandemia, mientras las construccion...
# 1bf09eeed12fc0dca53a30a742ed2cf1  Con los gimnasios cerrados debido al Covid-19 ...
# ...                                                                             ...
# caa470e258a8fabe409c660594ffb397  Desde Zacatecas nos cuentan que este fin de se...
# f7d345b304b60282d4bde07c06121152  Hace poco, el señor Ackerman equiparó a quiene...
# fb76b5597c8f404f97f4089393ea6344  Tras haber sido derrotado ampliamente en la el...
# 9004611e575e006ae18bc5a9e2193072  Poco a poco en algunos países del mundo, la in...
# ...

# %% [markdown]
# # Duplicate values

# %%
# 7. Eliminar valores duplicados

el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# c267d0c20793a5fdd61dfd9f753b58dc  Cuando los pulmones son débiles es más fácil q...
# 7ba0433f329bb63902f7e58e6de0cbba  La plática entre Pedro y su hijo fue interrump...
# 8fbe32c7fa43f2022ae7ef6336ff2f57  En los últimos cinco días hábiles de semana, q...
# 90af304f4d324a6d445e029897f989d5  Durante la pandemia, mientras las construccion...
# 1bf09eeed12fc0dca53a30a742ed2cf1  Con los gimnasios cerrados debido al Covid-19 ...
# ...                                                                             ...
# caa470e258a8fabe409c660594ffb397  Desde Zacatecas nos cuentan que este fin de se...
# f7d345b304b60282d4bde07c06121152  Hace poco, el señor Ackerman equiparó a quiene...
# fb76b5597c8f404f97f4089393ea6344  Tras haber sido derrotado ampliamente en la el...
# 9004611e575e006ae18bc5a9e2193072  Poco a poco en algunos países del mundo, la in...
# ...

# %% [markdown]
# # Descriptive analysis

# %%
clean_eluniversal = pd.read_csv('../web_scrapper/clean_eluniversal_2020_07_14_articles.csv')
clean_eltiempo = pd.read_csv('../web_scrapper/clean_eltiempo_2020_07_14_articles.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count      135.000000     135.000000
# mean         5.637037     240.266667
# std          1.930151     151.874025
# min          1.000000       9.000000
# 25%          4.500000     133.000000
# 50%          6.000000     205.000000
# 75%          7.000000     305.500000
# max         11.000000    1039.000000

# %%
clean_eltiempo.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       64.000000      64.000000
# mean         5.296875     319.968750
# std          1.497932     254.271881
# min          2.000000      11.000000
# 25%          4.000000     141.000000
# 50%          5.000000     302.000000
# 75%          6.000000     420.750000
# max          8.000000    1301.000000

# %%
# %matplotlib inline

# %%
clean_eltiempo['n_tokens_title'].plot(style='k.')
clean_eluniversal['n_tokens_title'].plot(style='r.')

# %%
clean_eltiempo['n_tokens_body'].plot(style='k.')
clean_eluniversal['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_eltiempo, clean_eluniversal])

grouped = all_newspapers.groupby('newspaper_uid')

grouped.hist()
# Out:
# newspaper_uid
# eltiempo       [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                min        mean   max
# newspaper_uid
# eltiempo        11  319.968750  1301
# eluniversal      9  240.266667  1039

# %%
grouped.plot()
# Out:
# newspaper_uid
# eltiempo       AxesSubplot(0.125,0.125;0.775x0.755)
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
